# %%
import pandas as pd
from sklearn import metrics
import numpy as np
import seaborn as sns
from matplotlib.colors import ListedColormap
from math import sqrt

areas = ['DK1','DK2']
files = ['consumption','price','wind']

data_dir = "../../data/data_sanitized/"
forecast_dir = '../../data/forecasts/wind/'

data = {}
for file in files:
    data[file] = {}
    for area in areas:
        data[file][area] = pd.read_csv(data_dir + file+"_"+ area+".csv")

models_variables = {'consumption':{
    'nordpool_prognosis': 1,
    "['dayofweek', 'consumption_prognosis']":2,
    "['dayofweek', 'consumption_prognosis', 'prev_day1', 'prev_day2', 'prev_day7']":3,
    "['dayofweek', 'consumption_prognosis', 'prev_day1', 'prev_day2', 'prev_day7', 'wind_prognosis']":4
},'wind':{
    'nordpool_prognosis': 1,
    "['dayofweek', 'wind_prognosis']": 2,
    "['dayofweek', 'wind_prognosis', 'prev_day1', 'prev_day2', 'prev_day7']": 3,
    "['dayofweek', 'wind_prognosis', 'prev_day1', 'prev_day2', 'prev_day7', 'consumption_prognosis']": 4
},'price':{
    "['dayofweek']": 1,
    "['dayofweek', 'prev_day1', 'prev_day2', 'prev_day7']": 2,
    "['dayofweek', 'prev_day1', 'prev_day2', 'prev_day7', 'min_day', 'max_day', 'last_val_day']": 3,
    "['dayofweek', 'prev_day1', 'prev_day2', 'prev_day7', 'min_day', 'max_day', 'last_val_day', 'consumption_prognosis', 'wind_prognosis']": 4
}}

# %%
def get_forecast_file(no):
    return pd.read_csv(forecast_dir + no +".csv")

# %%
forecasts_file = forecast_dir + 'files.txt'
forecasts = {}

with open(forecasts_file, 'r+') as f:
    lines = f.read().splitlines()
    if not lines:
        print('Empty file')
    for line in lines:
        cur_line = line.split('.', 1)
        no = cur_line[0]
        cur_line[1] =  cur_line[1].split('|')
        forecasts[no] = {"data":get_forecast_file(no),'file':cur_line[1][0],'area':cur_line[1][1],'window':cur_line[1][2],'start_date':cur_line[1][3],'last_date':cur_line[1][4], 'std_fn':cur_line[1][5], 'variables':cur_line[1][6]}

# %%
len(forecasts)
# Out:
# 168

# %%
fmae = {"consumption":{},"wind":{},"price":{}}
for f in forecasts:
    fc = forecasts[f]
    if not fc['area'] in fmae[fc['file']]:
        fmae[fc['file']][fc['area']] = {}
    if not fc['window'] in fmae[fc['file']][fc['area']]:
        fmae[fc['file']][fc['area']][fc['window']] = {}
    dates= fc['start_date'].replace('-','.') + '-' + fc['last_date'].replace('-','.')
    if not dates in fmae[fc['file']][fc['area']][fc['window']]:
        fmae[fc['file']][fc['area']][fc['window']][dates] = {}
    if not fc['std_fn'] in fmae[fc['file']][fc['area']][fc['window']][dates]:
        fmae[fc['file']][fc['area']][fc['window']][dates][fc['std_fn']] = {}
    model = 0
    if fc['variables'] in models_variables[fc['file']]:
        model = models_variables[fc['file']][fc['variables']]
        if not model in fmae[fc['file']][fc['area']][fc['window']][dates][fc['std_fn']]:
            fmae[fc['file']][fc['area']][fc['window']][dates][fc['std_fn']][model] = 0
        
#     '2020.01.01-2020.05.12': {'asinh': {1: 103.01720480684544,
#       2: 134.3635919242007,
#       3: 135.2235853394939,
#       4: 135.46573692235737},
#      'None': {2: 100.37606574242506,
#       3: 100.94307987530557,
#       4: 101.25232139428539}},
#     '2019.01.01-2020.05.12': {'asinh': {1: 93.43716166164405,
#       2: 113.68270942136299,
#       3: 114.0334469147955,
#       4: 113.88117485460845},
#      'None': {2: 92.54778098368666,
#       3: 92.7080857992261,
#       4: 92.7591995501219}}}}},
#  'price': {}}

# %%
df = pd.DataFrame.from_records(np.ones((1,1)))
# df['Area'] = ['DK1']*8+['DK2']*8
# df['Window'] = (['728']*4 + ['364']*4)*2
# df['Window'] = (['None']*4 + ['asinh']*4)*2
# df['Dates'] = (['2019.01.01-2019.12.31','2019.01.01-2020.05.12','2019.05.13-2020.05.12','2020.01.01-2020.05.12'])*4
df['Area'] = ['DK1']
df['Dates'] = ['2019.01.01-2019.12.31']
df['Window'] = ['182']

df = df.groupby(['Area','Dates','Window']).sum()
# df = df.rename(columns={0:1,1:3,2:4,3:5})


file = 'wind'
for area in fmae[file]:
    for window in fmae[file][area]:
        for dates in fmae[file][area][window]:
            for std_fn in fmae[file][area][window][dates]:
                for model in fmae[file][area][window][dates][std_fn]:
                    model_col = 'Model ' + str(model) + " ("+std_fn+")"
                    df.loc[(area,dates,window),model_col] = fmae[file][area][window][dates][std_fn][model]

                    
df = df.drop(columns=[0])
df = df[df.index.get_level_values(0) == 'DK2']
df = df.sort_index()
cm = ListedColormap(sns.color_palette('Purples',20).as_hex())
cm2 = ListedColormap(sns.color_palette('Greens',20).as_hex())
display = df.style.background_gradient(cmap=cm,axis=None)

display
# Out:
# <style  type="text/css" >
#     #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row0_col0 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row0_col1 {
#             background-color:  #8d89c0;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row0_col2 {
#             background-color:  #817ebb;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row0_col3 {
#             background-color:  #8d89c0;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row0_col4 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row0_col5 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row0_col6 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row1_col0 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row1_col1 {
#             background-color:  #a4a1cc;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row1_col2 {
#             background-color:  #a4a1cc;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row1_col3 {
#             background-color:  #afaed4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row1_col4 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row1_col5 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row1_col6 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row2_col0 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row2_col1 {
#             background-color:  #c6c7e1;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row2_col2 {
#             background-color:  #c6c7e1;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row2_col3 {
#             background-color:  #c6c7e1;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row2_col4 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row2_col5 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row2_col6 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row3_col0 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row3_col1 {
#             background-color:  #817ebb;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row3_col2 {
#             background-color:  #817ebb;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row3_col3 {
#             background-color:  #817ebb;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row3_col4 {
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row3_col5 {
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row3_col6 {
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row4_col0 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row4_col1 {
#             background-color:  #9894c5;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row4_col2 {
#             background-color:  #8d89c0;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row4_col3 {
#             background-color:  #9894c5;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row4_col4 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row4_col5 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row4_col6 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row5_col0 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row5_col1 {
#             background-color:  #9894c5;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row5_col2 {
#             background-color:  #9894c5;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row5_col3 {
#             background-color:  #9894c5;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row5_col4 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row5_col5 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row5_col6 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row6_col0 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row6_col1 {
#             background-color:  #817ebb;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row6_col2 {
#             background-color:  #796eb2;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row6_col3 {
#             background-color:  #796eb2;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row6_col4 {
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row6_col5 {
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row6_col6 {
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row7_col0 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row7_col1 {
#             background-color:  #afaed4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row7_col2 {
#             background-color:  #afaed4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row7_col3 {
#             background-color:  #afaed4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row7_col4 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row7_col5 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row7_col6 {
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row8_col0 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row8_col1 {
#             background-color:  #9894c5;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row8_col2 {
#             background-color:  #9894c5;
#             color:  #000000;
#         }    #T_a9c179e6_ae53_11ea_bc8c_af15b76e9460row8_col3 {
#             background-color:  #9894c5;
#             color:  #000000;

# %%
df[df.index.get_level_values(0) == 'DK1']
# Out:
# Empty DataFrame
# Columns: [Model 3 (None), Model 1 (None), Model 2 (None), Model 4 (None), Model 3 (asinh), Model 1 (asinh), Model 2 (asinh), Model 4 (asinh)]
# Index: []

# %%
display
# Out:
# <style  type="text/css" >
#     #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow0_col0 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow0_col1 {
#             background-color:  #e4e3f0;
#             color:  #000000;
#             background-color:  #e4e3f0;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow0_col2 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow0_col3 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow0_col4 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow0_col5 {
#             background-color:  #e4e3f0;
#             color:  #000000;
#             background-color:  #e4e3f0;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow0_col6 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow0_col7 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow1_col0 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow1_col1 {
#             background-color:  #dcdcec;
#             color:  #000000;
#             background-color:  #dcdcec;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow1_col2 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow1_col3 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow1_col4 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow1_col5 {
#             background-color:  #dcdcec;
#             color:  #000000;
#             background-color:  #dcdcec;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow1_col6 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow1_col7 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow2_col0 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow2_col1 {
#             background-color:  #e4e3f0;
#             color:  #000000;
#             background-color:  #e4e3f0;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow2_col2 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow2_col3 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow2_col4 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow2_col5 {
#             background-color:  #e4e3f0;
#             color:  #000000;
#             background-color:  #e4e3f0;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow2_col6 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow2_col7 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow3_col0 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow3_col1 {
#             background-color:  #d1d2e7;
#             color:  #000000;
#             background-color:  #d1d2e7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow3_col2 {
#             background-color:  #ecebf4;
#             color:  #000000;
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow3_col3 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow3_col4 {
#             background-color:  #ecebf4;
#             color:  #000000;
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow3_col5 {
#             background-color:  #d1d2e7;
#             color:  #000000;
#             background-color:  #d1d2e7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow3_col6 {
#             background-color:  #ecebf4;
#             color:  #000000;
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow3_col7 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow4_col0 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow4_col1 {
#             background-color:  #c6c7e1;
#             color:  #000000;
#             background-color:  #c6c7e1;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow4_col2 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow4_col3 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow4_col4 {
#             background-color:  #f2f0f7;
#             color:  #000000;
#             background-color:  #f2f0f7;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow4_col5 {
#             background-color:  #bbbbdb;
#             color:  #000000;
#             background-color:  #bbbbdb;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow4_col6 {
#             background-color:  #ecebf4;
#             color:  #000000;
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_d32d14b6_ae0d_11ea_a041_8dd86313cb3arow4_col7 {
#             background-color:  #f2f0f7;
